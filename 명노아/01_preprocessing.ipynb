# %%
from torchvision.datasets import ImageFolder
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms
import cv2
import numpy as np
import pandas as pd
# Out:
# c:\Users\mathn\.conda\envs\Torch_PY38\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] 지정된 프로시저를 찾을 수 없습니다'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
data = ImageFolder(root = "./add_data", transform=transforms.ToTensor())

# %%
def extract_file_names(file_list):
    file_names = []
    for file_path, _ in file_list:
        file_names.append(file_path)
    return file_names

file_names = extract_file_names(data.imgs)
len(file_names), file_names # 사진 총 181장, 파일이름 출력
# Out:
# (422,
#  ["./add_data\\mop\\';laf.jpg",
#   './add_data\\mop\\0a68f7.jpg',
#   './add_data\\mop\\1.jpg',
#   './add_data\\mop\\10.jpg',
#   './add_data\\mop\\104.jpg',
#   './add_data\\mop\\105.jpg',
#   './add_data\\mop\\106.jpg',
#   './add_data\\mop\\108.jpg',
#   './add_data\\mop\\110.jpg',
#   './add_data\\mop\\112.jpg',
#   './add_data\\mop\\114.jpg',
#   './add_data\\mop\\115.jpg',
#   './add_data\\mop\\118.jpg',
#   './add_data\\mop\\12.jpg',
#   './add_data\\mop\\120.jpg',
#   './add_data\\mop\\121.jpg',
#   './add_data\\mop\\12132.jpg',
#   './add_data\\mop\\123123.jpg',
#   './add_data\\mop\\126.jpg',
#   './add_data\\mop\\13.jpg',
#   './add_data\\mop\\134.jpg',
#   './add_data\\mop\\13414.jpg',
#   './add_data\\mop\\14.jpg',
#   './add_data\\mop\\144.jpg',
#   './add_data\\mop\\15.jpg',
#   './add_data\\mop\\150.jpg',
#   './add_data\\mop\\155.jpg',
#   './add_data\\mop\\157.jpg',
#   './add_data\\mop\\16.jpg',
#   './add_data\\mop\\163.jpg',
#   './add_data\\mop\\17.jpg',
#   './add_data\\mop\\182.jpg',
#   './add_data\\mop\\184.jpg',
#   './add_data\\mop\\19.jpg',
#   './add_data\\mop\\198.jpg',
#   './add_data\\mop\\20.jpg',
#   './add_data\\mop\\22.jpg',
#   './add_data\\mop\\23.jpg',
#   './add_data\\mop\\24.jpg',
#   './add_data\\mop\\25.jpg',
#   './add_data\\mop\\26.jpg',
#   './add_data\\mop\\27.jpg',
#   './add_data\\mop\\28.jpg',
#   './add_data\\mop\\29.jpg',
#   './add_data\\mop\\2e121.jpg',
#   './add_data\\mop\\2erhowef.jpg',
#   './add_data\\mop\\30.jpg',
#   './add_data\\mop\\300.jpg',
#   './add_data\\mop\\301.jpg',
#   './add_data\\mop\\302.jpg',
#   './add_data\\mop\\306.jpg',
#   './add_data\\mop\\307.jpg',
#   './add_data\\mop\\308.jpg',
#   './add_data\\mop\\310.jpg',
#   './add_data\\mop\\311.jpg',
#   './add_data\\mop\\312.jpg',
#   './add_data\\mop\\314.jpg',
#   './add_data\\mop\\315.jpg',
#   './add_data\\mop\\317.jpg',
#   './add_data\\mop\\318.jpg',
#   './add_data\\mop\\319.jpg',
#   './add_data\\mop\\320.jpg',
#   './add_data\\mop\\324.jpg',
#   './add_data\\mop\\325.jpg',
#   './add_data\\mop\\326.jpg',
#   './add_data\\mop\\328.jpg',
#   './add_data\\mop\\329.jpg',
#   './add_data\\mop\\330.jpg',
#   './add_data\\mop\\331.jpg',
#   './add_data\\mop\\332.jpg',
#   './add_data\\mop\\333.jpg',
#   './add_data\\mop\\335.jpg',
#   './add_data\\mop\\336.jpg',
#   './add_data\\mop\\337.jpg',
#   './add_data\\mop\\340.jpg',
#   './add_data\\mop\\342.jpg',
#   './add_data\\mop\\343.jpg',
#   './add_data\\mop\\345.jpg',
#   './add_data\\mop\\346.jpg',
#   './add_data\\mop\\349.jpg',
#   './add_data\\mop\\352.jpg',
#   './add_data\\mop\\356.jpg',
#   './add_data\\mop\\357.jpg',
#   './add_data\\mop\\358.jpg',
#   './add_data\\mop\\36.jpg',
#   './add_data\\mop\\361.jpg',
#   './add_data\\mop\\363.jpg',
#   './add_data\\mop\\366.jpg',
#   './add_data\\mop\\367.jpg',
#   './add_data\\mop\\37.jpg',
#   './add_data\\mop\\372.jpg',
#   './add_data\\mop\\373.jpg',
#   './add_data\\mop\\375.jpg',
#   './add_data\\mop\\376.jpg',
#   './add_data\\mop\\379.jpg',
#   './add_data\\mop\\38.jpg',
#   './add_data\\mop\\380.jpg',
#   './add_data\\mop\\381.jpg',
#   './add_data\\mop\\382.jpg',
#   './add_data\\mop\\383.jpg',
#   './add_data\\mop\\385.jpg',
#   './add_data\\mop\\39.jpg',
#   './add_data\\mop\\391.jpg',
#   './add_data\\mop\\40.jpg',
#   './add_data\\mop\\45.jpg',
#   './add_data\\mop\\48.jpg',
#   './add_data\\mop\\51.jpg',
#   './add_data\\mop\\52.jpg',
#   './add_data\\mop\\53.jpg',
#   './add_data\\mop\\56.jpg',
#   './add_data\\mop\\59.jpg',
#   './add_data\\mop\\61.jpg',
#   './add_data\\mop\\63.jpg',
#   './add_data\\mop\\64.jpg',
#   './add_data\\mop\\68.jpg',
#   './add_data\\mop\\71.jpg',
#   './add_data\\mop\\74.jpg',
#   './add_data\\mop\\76.jpg',
#   './add_data\\mop\\78.jpg',
#   './add_data\\mop\\79.jpg',
#   './add_data\\mop\\7dfydf.jpg',
#   './add_data\\mop\\7g.jpg',
#   './add_data\\mop\\8.jpg',
#   './add_data\\mop\\82.jpg',
#   './add_data\\mop\\85.jpg',
#   './add_data\\mop\\87.jpg',
#   './add_data\\mop\\89.jpg',
#   './add_data\\mop\\9.jpg',
#   './add_data\\mop\\90dv.jpg',
#   './add_data\\mop\\92.jpg',
#   './add_data\\mop\\979sfd.jpg',
#   './add_data\\mop\\987a0dsf.jpg',
#   './add_data\\mop\\98effds.jpg',
#   './add_data\\mop\\a.jpg',
#   './add_data\\mop\\adf98u.jpg',
#   './add_data\\mop\\adfsligu.jpg',
#   './add_data\\mop\\ads70.jpg',
#   './add_data\\mop\\adsf8907.jpg',
#   './add_data\\mop\\adsflh.jpg',
#   './add_data\\mop\\adsfliuhih.jpg',
#   './add_data\\mop\\adsflkjh.jpg',
#   './add_data\\mop\\aef98.jpg',
#   './add_data\\mop\\aefo8.jpg',
#   './add_data\\mop\\af098.jpg',
#   './add_data\\mop\\af0ew789.jpg',
#   './add_data\\mop\\af906.jpg',
#   './add_data\\mop\\aisdfg.jpg',
#   './add_data\\mop\\ao9of8y8.jpg',
#   './add_data\\mop\\aof67.jpg',
#   './add_data\\mop\\aos8df7632.jpg',
#   './add_data\\mop\\aosdf87.jpg',
#   './add_data\\mop\\ap9sdf8y9pf.jpg',
#   './add_data\\mop\\as90df8.jpg',
#   './add_data\\mop\\asdf,g.jpg',
#   './add_data\\mop\\asdf,kj.jpg',
#   './add_data\\mop\\asdf0978.jpg',
#   './add_data\\mop\\asdf8907.jpg',
#   './add_data\\mop\\asdf9073.jpg',
#   './add_data\\mop\\asdf9678.jpg',
#   './add_data\\mop\\asdf9807.jpg',
#   './add_data\\mop\\asdfklhja.jpg',
#   './add_data\\mop\\asdfkljh.jpg',
#   './add_data\\mop\\asdfkljhj.jpg',
#   './add_data\\mop\\asdflh.jpg',
#   './add_data\\mop\\asdfljh.jpg',
#   './add_data\\mop\\asdflkk.jpg',
#   './add_data\\mop\\asdfo7.jpg',
#   './add_data\\mop\\asdfo7y.jpg',
#   './add_data\\mop\\asdfoiha.jpg',
#   './add_data\\mop\\asdfoiuy.jpg',
#   './add_data\\mop\\asdfp098.jpg',
#   './add_data\\mop\\asdfp978.jpg',
#   './add_data\\mop\\asdfp98.jpg',
#   './add_data\\mop\\asdfs,hgh.jpg',
#   './add_data\\mop\\asdlfkj.jpg',
#   './add_data\\mop\\asdo88ya3.jpg',
#   "./add_data\\mop\\asdof980'.jpg",
#   './add_data\\mop\\asdp9f8y.jpg',
#   './add_data\\mop\\asfdlihu.jpg',
#   './add_data\\mop\\aspdf9878fdas.jpg',
#   './add_data\\mop\\awefliuh.jpg',
#   './add_data\\mop\\awfewpuy.jpg',
#   './add_data\\mop\\b.jpg',
#   './add_data\\mop\\c.jpg',
#   "./add_data\\mop\\d7f7'.jpg",
#   './add_data\\mop\\df .jpg',
#   './add_data\\mop\\dfasf906.jpg',
#   './add_data\\mop\\dfo.jpg',
#   './add_data\\mop\\did.jpg',
#   './add_data\\mop\\dsa789.jpg',
#   './add_data\\mop\\dv9uhdsf.jpg',
#   './add_data\\mop\\e.jpg',
#   './add_data\\mop\\f.jpg',
#   './add_data\\mop\\fdspa978.jpg',
#   './add_data\\mop\\foe8763i.jpg',
#   './add_data\\mop\\g.jpg',
#   './add_data\\mop\\h .jpg',
#   "./add_data\\mop\\jhj'.jpg",
#   './add_data\\mop\\ksjdfh.jpg',
#   './add_data\\mop\\mnmn.jpg',
#   './add_data\\mop\\od8v876vf.jpg',
#   './add_data\\mop\\q22.jpg',
#   './add_data\\mop\\q23ighu44.jpg',
#   './add_data\\mop\\qewrf.jpg',
#   './add_data\\mop\\qwwq.jpg',
#   './add_data\\mop\\s8df763.jpg',
#   './add_data\\mop\\sdfajhfds.jpg',
#   './add_data\\mop\\sdfd.jpg',
#   './add_data\\mop\\sdfgf.jpg',
#   './add_data\\mop\\sdfmb.jpg',
#   './add_data\\mop\\smdqw.jpg',
#   './add_data\\mop\\smlnqww.jpg',
#   './add_data\\mop\\y.jpg',
#   './add_data\\mop_dog\\0.jpg',
#   './add_data\\mop_dog\\0908dsf09.jpg',
#   './add_data\\mop_dog\\09adsf7f0.jpg',
#   './add_data\\mop_dog\\10.jpg',
#   './add_data\\mop_dog\\102.jpg',
#   './add_data\\mop_dog\\11.jpg',
#   './add_data\\mop_dog\\12.jpg',
#   './add_data\\mop_dog\\12d.jpg',
#   './add_data\\mop_dog\\138.jpg',
#   './add_data\\mop_dog\\139.jpg',
#   './add_data\\mop_dog\\14.jpg',
#   './add_data\\mop_dog\\153.jpg',
#   './add_data\\mop_dog\\16.jpg',
#   './add_data\\mop_dog\\185.jpg',
#   './add_data\\mop_dog\\187.jpg',
#   './add_data\\mop_dog\\188.jpg',
#   './add_data\\mop_dog\\19.jpg',
#   './add_data\\mop_dog\\196.jpg',
#   './add_data\\mop_dog\\20.jpg',
#   './add_data\\mop_dog\\200.jpg',
#   './add_data\\mop_dog\\201.jpg',
#   './add_data\\mop_dog\\202.jpg',
#   './add_data\\mop_dog\\21.jpg',
#   './add_data\\mop_dog\\22.jpg',
#   './add_data\\mop_dog\\23.jpg',
#   './add_data\\mop_dog\\230.jpg',
#   './add_data\\mop_dog\\234.jpg',
#   './add_data\\mop_dog\\24.jpg',
#   './add_data\\mop_dog\\244.jpg',
#   './add_data\\mop_dog\\25.jpg',
#   './add_data\\mop_dog\\253.jpg',
#   './add_data\\mop_dog\\254.jpg',
#   './add_data\\mop_dog\\257.jpg',
#   './add_data\\mop_dog\\26.jpg',
#   './add_data\\mop_dog\\27.jpg',
#   './add_data\\mop_dog\\270.jpg',
#   './add_data\\mop_dog\\271.jpg',
#   './add_data\\mop_dog\\277.jpg',
#   './add_data\\mop_dog\\281.jpg',
#   './add_data\\mop_dog\\287.jpg',
#   './add_data\\mop_dog\\294.jpg',
#   './add_data\\mop_dog\\299.jpg',
#   './add_data\\mop_dog\\2c.jpg',
#   './add_data\\mop_dog\\3.jpg',
#   './add_data\\mop_dog\\300.jpg',
#   './add_data\\mop_dog\\302.jpg',
#   './add_data\\mop_dog\\304.jpg',
#   './add_data\\mop_dog\\305.jpg',
#   './add_data\\mop_dog\\308.jpg',
#   './add_data\\mop_dog\\309.jpg',
#   './add_data\\mop_dog\\310.jpg',
#   './add_data\\mop_dog\\311.jpg',
#   './add_data\\mop_dog\\312.jpg',
#   './add_data\\mop_dog\\314.jpg',
#   './add_data\\mop_dog\\315.jpg',
#   './add_data\\mop_dog\\316.jpg',
#   './add_data\\mop_dog\\319.jpg',
#   './add_data\\mop_dog\\320.jpg',
#   './add_data\\mop_dog\\321.jpg',
#   './add_data\\mop_dog\\322.jpg',
#   './add_data\\mop_dog\\327.jpg',
#   './add_data\\mop_dog\\33.jpg',
#   './add_data\\mop_dog\\330.jpg',
#   './add_data\\mop_dog\\331.jpg',
#   './add_data\\mop_dog\\337.jpg',
#   './add_data\\mop_dog\\34.jpg',
#   './add_data\\mop_dog\\341.jpg',
#   './add_data\\mop_dog\\342.jpg',
#   './add_data\\mop_dog\\343.jpg',
#   './add_data\\mop_dog\\344.jpg',
#   './add_data\\mop_dog\\35.jpg',
#   './add_data\\mop_dog\\351.jpg',
#   './add_data\\mop_dog\\354.jpg',
#   './add_data\\mop_dog\\358.jpg',
#   './add_data\\mop_dog\\359.jpg',
#   './add_data\\mop_dog\\36.jpg',
#   './add_data\\mop_dog\\362.jpg',
#   './add_data\\mop_dog\\37.jpg',
#   './add_data\\mop_dog\\370.jpg',
#   './add_data\\mop_dog\\371.jpg',
#   './add_data\\mop_dog\\374.jpg',
#   './add_data\\mop_dog\\375.jpg',
#   './add_data\\mop_dog\\379.jpg',
#   './add_data\\mop_dog\\38.jpg',
#   './add_data\\mop_dog\\380.jpg',
#   './add_data\\mop_dog\\381.jpg',
#   './add_data\\mop_dog\\385.jpg',
#   './add_data\\mop_dog\\387.jpg',
#   './add_data\\mop_dog\\388.jpg',
#   './add_data\\mop_dog\\39.jpg',
#   './add_data\\mop_dog\\391.jpg',
#   './add_data\\mop_dog\\392.jpg',
#   './add_data\\mop_dog\\393.jpg',
#   './add_data\\mop_dog\\394.jpg',
#   './add_data\\mop_dog\\395.jpg',
#   './add_data\\mop_dog\\4.jpg',
#   './add_data\\mop_dog\\40.jpg',
#   './add_data\\mop_dog\\41.jpg',
#   './add_data\\mop_dog\\42.jpg',
#   './add_data\\mop_dog\\44.jpg',
#   './add_data\\mop_dog\\4]sdf.jpg',
#   './add_data\\mop_dog\\5.jpg',
#   './add_data\\mop_dog\\52.jpg',
#   './add_data\\mop_dog\\57.jpg',
#   './add_data\\mop_dog\\6.jpg',
#   './add_data\\mop_dog\\62.jpg',
#   './add_data\\mop_dog\\68.jpg',
#   './add_data\\mop_dog\\69.jpg',
#   './add_data\\mop_dog\\7.jpg',
#   './add_data\\mop_dog\\70.jpg',
#   './add_data\\mop_dog\\74.jpg',
#   './add_data\\mop_dog\\79.jpg',
#   './add_data\\mop_dog\\8.jpg',
#   './add_data\\mop_dog\\80.jpg',
#   './add_data\\mop_dog\\84.jpg',
#   './add_data\\mop_dog\\85.jpg',
#   './add_data\\mop_dog\\87.jpg',
#   './add_data\\mop_dog\\89.jpg',
#   './add_data\\mop_dog\\9.jpg',
#   './add_data\\mop_dog\\91.jpg',
#   './add_data\\mop_dog\\92.jpg',
#   './add_data\\mop_dog\\95.jpg',
#   './add_data\\mop_dog\\97.jpg',
#   './add_data\\mop_dog\\a9sdf8y.jpg',
#   './add_data\\mop_dog\\adflh.jpg',
#   './add_data\\mop_dog\\adflj.jpg',
#   './add_data\\mop_dog\\adfmnb.jpg',
#   './add_data\\mop_dog\\admnbds.jpg',
#   './add_data\\mop_dog\\ads908adf.jpg',
#   './add_data\\mop_dog\\adsfds2.jpg',
#   './add_data\\mop_dog\\adsfhjk.jpg',
#   './add_data\\mop_dog\\adsflkj.jpg',
#   './add_data\\mop_dog\\adslkdfh.jpg',
#   './add_data\\mop_dog\\aefkuig.jpg',
#   './add_data\\mop_dog\\afkljh.jpg',
#   './add_data\\mop_dog\\aflhd.jpg',
#   './add_data\\mop_dog\\afljkh.jpg',
#   './add_data\\mop_dog\\aflkjhj.jpg',
#   './add_data\\mop_dog\\afwhefjwa.jpg',
#   './add_data\\mop_dog\\aksdfj.jpg',
#   './add_data\\mop_dog\\as9df87.jpg',
#   './add_data\\mop_dog\\asdfflk.jpg',
#   './add_data\\mop_dog\\asdfg.jpg',
#   "./add_data\\mop_dog\\asdfh'[.jpg",
#   './add_data\\mop_dog\\asdfipuy.jpg',
#   './add_data\\mop_dog\\asdfkg.jpg',
#   './add_data\\mop_dog\\asdfl.jpg',
#   './add_data\\mop_dog\\asdflh.jpg',
#   './add_data\\mop_dog\\asdflhjk.jpg',
#   './add_data\\mop_dog\\asdfljk.jpg',
#   './add_data\\mop_dog\\asdflkhj.jpg',
#   './add_data\\mop_dog\\asdflkjh.jpg',
#   './add_data\\mop_dog\\asdflkjk.jpg',
#   './add_data\\mop_dog\\asdfluih.jpg',
#   './add_data\\mop_dog\\asdfmn.jpg',
#   './add_data\\mop_dog\\asdfmnb.jpg',
#   './add_data\\mop_dog\\asdfmnbv.jpg',
#   './add_data\\mop_dog\\asdfpio.jpg',
#   './add_data\\mop_dog\\asdfpoiu.jpg',
#   './add_data\\mop_dog\\asdfsuio.jpg',
#   './add_data\\mop_dog\\asfdlkjh.jpg',
#   './add_data\\mop_dog\\asflhk.jpg',
#   './add_data\\mop_dog\\aso.jpg',
#   './add_data\\mop_dog\\df.m,.m.jpg',
#   './add_data\\mop_dog\\df99fd.jpg',
#   './add_data\\mop_dog\\dfalh.jpg',
#   './add_data\\mop_dog\\dfgdopwe.jpg',
#   './add_data\\mop_dog\\dflskjb.jpg',
#   './add_data\\mop_dog\\epu].jpg',
#   './add_data\\mop_dog\\eqe2.jpg',
#   './add_data\\mop_dog\\eqworoui.jpg',
#   './add_data\\mop_dog\\erepoi.jpg',
#   './add_data\\mop_dog\\ghsdf.jpg',
#   './add_data\\mop_dog\\ladsfjkh.jpg',
#   './add_data\\mop_dog\\lxkzcj.jpg',
#   './add_data\\mop_dog\\poiewrqu.jpg',
#   './add_data\\mop_dog\\qerpiu.jpg',
#   './add_data\\mop_dog\\qerpu.jpg',
#   './add_data\\mop_dog\\qewreliur.jpg',
#   './add_data\\mop_dog\\qewrlhjk.jpg',
#   './add_data\\mop_dog\\qwerliui.jpg',
#   './add_data\\mop_dog\\sad.f.jpg',
#   './add_data\\mop_dog\\sadfg.jpg',
#   './add_data\\mop_dog\\sadfkj.jpg',
#   './add_data\\mop_dog\\sadfl.jpg',
#   './add_data\\mop_dog\\sadflj.jpg',
#   './add_data\\mop_dog\\sadlfh.jpg',
#   './add_data\\mop_dog\\sd..jpg',
#   './add_data\\mop_dog\\skvcjv.jpg',
#   './add_data\\mop_dog\\we0.jpg',
#   './add_data\\mop_dog\\we09fd.jpg',
#   './add_data\\mop_dog\\wef.jpg',
#   './add_data\\mop_dog\\wef23.jpg',
#   './add_data\\mop_dog\\wepoiw.jpg',
#   './add_data\\mop_dog\\wer.jpg',
#   './add_data\\mop_dog\\werio.jpg',
#   './add_data\\mop_dog\\weriu.jpg',
#   './add_data\\mop_dog\\weroui.jpg',
#   './add_data\\mop_dog\\werouio.jpg',
#   './add_data\\mop_dog\\werpiou.jpg',
#   './add_data\\mop_dog\\wewoiiew.jpg',
#   './add_data\\mop_dog\\wfe.jpg',
#   './add_data\\mop_dog\\wlerihwe.jpg',
#   './add_data\\mop_dog\\wpeor.jpg',
#   './add_data\\mop_dog\\wqerpi.jpg',
#   './add_data\\mop_dog\\wqeryr.jpg',
#   './add_data\\mop_dog\\wqeryuio.jpg',
#   './add_data\\mop_dog\\wqpoioqw.jpg',
#   './add_data\\mop_dog\\z,jb.jpg'])

# %%
import cv2
import numpy as np


isDragging = False                     
x0, y0, w, h = -1,-1,-1,-1              
blue, red = (255,0,0),(0,0,255)        

def onMouse(event,x,y,flags,param):    
    global isDragging, x0, y0, img      # 전역변수 참조
    if event == cv2.EVENT_LBUTTONDOWN:  # 왼쪽 마우스 버튼 다운
        isDragging = True
        x0 = x
        y0 = y
    elif event == cv2.EVENT_MOUSEMOVE:  # 마우스 움직임
        if isDragging:                  # 드래그 진행 중
            img_draw = img.copy()
            cv2.rectangle(img_draw, (x0, y0), (x, y), blue, 2) # 드래그 진행 영역 표시
            cv2.imshow('img', img_draw) # 사각형 표시된 그림 화면 출력
    elif event == cv2.EVENT_LBUTTONUP:  # 왼쪽 마우스 버튼 업
        if isDragging:                  # 드래그 중지
            isDragging = False          
            w = x - x0                  # 폭 계산
            h = y - y0                  # 높이 계산
            print("x:%d, y:%d, w:%d, h:%d" % (x0, y0, w, h))
            if w > 0 and h > 0:         # 왼쪽에서 오른쪽으로 긁었을 때, 
                img_draw = img.copy()   # 선택 영역에 사각형 그림을 표시할 이미지 복제
                # 선택 영역에 빨간 사각형 표시
                cv2.rectangle(img_draw, (x0, y0), (x, y), red, 2) 
                cv2.imshow('img', img_draw) # 빨간 사각형 그려진 이미지 화면 출력
                roi = img[y0:y0+h, x0:x0+w] # 원본 이미지에서 선택 영역만 ROI로 지정
                cv2.imshow('cropped', roi)  # ROI 지정 영역을 새창으로 표시
                cv2.moveWindow('cropped', 0, 0) # 새창을 화면 좌측 상단에 이동
                cv2.imwrite(param, roi)   # ROI 영역만 파일로 저장
                print("croped.")
            else:
                cv2.imshow('img', img)  # 드래그 방향이 잘못된 경우 사각형 그림이 없는 원본 이미지 출력
                print("좌측 상단에서 우측 하단으로 영역을 드래그 하세요.")

for i in file_names:
    try :
        img = cv2.imread(i)
        cv2.imshow('img', img)
        cv2.setMouseCallback('img', onMouse, param=i)
        cv2.waitKey()
        cv2.destroyAllWindows()
    except : # 그림이 열리지 않는 경우도 있어서, 이를 감안하여 try, catch구문 활용 
        pass
